# %% [markdown]
# ## [作業目標]
# 了解機器學習適合應用的領域與範疇。

# %% [markdown]
# ## [作業重點]
# 透過瞭解機器學習的運作方式，找出非常適用機器學習應用的領域及其原因

# %% [markdown]
# ## 作業
# 請找出一個你認為機器學習可以發光發熱的領域並闡述原因?

# %%
   我認為機器學習可以應用在醫療上
   在生物領域上有許多的生物資料
   除了患者的基本資料外
   還可以有患者的基因序列等
   在這樣的狀況下
   我們可以透過許多的資料結合生物上的知識
   利用機器學習找出適合不同病患的不同治療方法
   達到現在醫療領域的研究上想達到的精準醫療等
